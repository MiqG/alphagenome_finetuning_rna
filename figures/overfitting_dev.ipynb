# %% [markdown]
# # Overfitting single intervals

# %% [markdown]
# ## imports

# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from figutils import (
    cm,
    set_figure_style, 
)

set_figure_style()

PAL_MODALITIES = {
    "rna_seq": "#717EC3",
    "splice_site": "#AE8799",
    "splice_usage": "#C95D63",
    "splice_junctions": "#EE8434"
}

MAP_MODALITIES = {
    "rna_seq_1bp_profile_pearson_r_mean":"rna_seq",
    "splice_site_auprc_macro":"splice_site",
    "splice_usage_pearson_r":"splice_usage",
    "splice_junctions_pearson_r":"splice_junctions"
}

OUTPUT_DIR = os.path.join("pdfs","overfitting_dev")
os.makedirs(OUTPUT_DIR, exist_ok=True)

# %% [markdown]
# ## data

# %%
# paths

ROOT = ".."
OUTPUT_DIR = os.path.join(ROOT,"results/finetuning/alphagenome_pytorch/overfitting/dev")

logs_file = os.path.join(OUTPUT_DIR, "summary", "epoch_logs.parquet")

# %%
# loads

logs = pd.read_parquet(logs_file)

# %% [markdown]
# ## figures

# %%
logs.value_counts(["run_name"])
# Out:
# run_name
# debug_splice_junctions__randinit__origloss__annotated__frozen     10
# debug_splice_junctions__randinit__origloss__annotated__lora       10
# debug_splice_junctions__randinit__origloss__predicted__frozen     10
# debug_splice_junctions__randinit__origloss__predicted__lora       10
# debug_splice_junctions__randinit__newloss__annotated__frozen      10
# debug_splice_junctions__randinit__newloss__annotated__lora        10
# debug_splice_junctions__randinit__newloss__predicted__frozen      10
# debug_splice_junctions__randinit__newloss__predicted__lora        10
# debug_splice_junctions__pretrinit__origloss__annotated__frozen    10
# debug_splice_junctions__pretrinit__origloss__annotated__lora      10
# debug_splice_junctions__pretrinit__origloss__predicted__frozen    10
# debug_splice_junctions__pretrinit__origloss__predicted__lora      10
# debug_splice_junctions__pretrinit__newloss__annotated__frozen     10
# debug_splice_junctions__pretrinit__newloss__annotated__lora       10
# debug_splice_junctions__pretrinit__newloss__predicted__frozen     10
# debug_splice_junctions__pretrinit__newloss__predicted__lora       10
# Name: count, dtype: int64

# %% [markdown]
# ### splice site and junction heads struggle to overfit a single interval

# %%
runs_oi = [
    "debug_splice_junctions__randinit__origloss__annotated__frozen",
    "debug_splice_junctions__randinit__newloss__annotated__frozen",
    "debug_splice_junctions__pretrinit__origloss__annotated__frozen",
    "debug_splice_junctions__pretrinit__newloss__annotated__frozen"
]
X = logs#.query("run_name.isin(@runs_oi)")

# %%
x = (
    X[
        ["epoch","run_name","val_loss_rna_seq_loss","val_loss_splice_site_loss","val_loss_splice_usage_loss","val_loss_splice_junctions_loss"]
    ].drop_duplicates()
    .melt(id_vars=["epoch","run_name"], var_name="modality", value_name="loss")
    .assign(modality=lambda d: d["modality"].str.replace("val_loss_","").str.replace("_loss",""))
)

g = sns.relplot(
    kind="line",
    data=x,
    x="epoch",
    y="loss",
    hue="run_name", palette="tab20",
    col="modality", col_order=PAL_MODALITIES.keys(),
    linewidth=1,
    facet_kws=dict(sharey=False),
    height=4*cm, aspect=0.9
)

g.set(
    xlabel="Epoch",
    ylabel="Loss",
    yscale="log",
)
g.legend.set_title("")
g.fig.subplots_adjust(top=0.8)
g.fig.suptitle("Single-interval overfitting (RNAcov + SSProb + SSU + SJ)")

plt.show()

# %%
x = pd.concat([
    (
        X[
            ["epoch","run_name","train_rna_seq_1bp_profile_pearson_r_mean","train_splice_usage_pearson_r","train_splice_junctions_pearson_r"]
        ].drop_duplicates()
        .melt(id_vars=["epoch","run_name"], var_name="modality", value_name="metric_value")
        .assign(metric_name="correlation")
    ),
    (
        X[
            ["epoch","run_name","train_splice_site_auprc_macro"]
        ].drop_duplicates()
        .melt(id_vars=["epoch","run_name"], var_name="modality", value_name="metric_value")
        .assign(metric_name="auprc")
    )
])
x["modality"] = x["modality"].map({
    "train_rna_seq_1bp_profile_pearson_r_mean":"rna_seq",
    "splice_site_auprc_macro":"splice_site",
    "train_splice_site_auprc_macro":"splice_site",
    "train_splice_usage_pearson_r":"splice_usage",
    "train_splice_junctions_pearson_r":"splice_junctions",
    "train_splice_junctions_pearson_r_nonzero":"splice_junctions",
    "train_splice_junctions_pearson_r_donor_marginal":"splice_junctions",
    "train_splice_junctions_pearson_r_acceptor_marginal":"splice_junctions",
})

g = sns.relplot(
    kind="line",
    data=x,
    x="epoch",
    y="metric_value",
    hue="run_name", palette="tab20",
    col="modality", col_order=PAL_MODALITIES.keys(),
    linewidth=1, linestyle="dashed",
    facet_kws=dict(sharey=False),
    height=4*cm, aspect=0.9
)

g.set(
    xlabel="Epoch",
    ylabel="Metric"
)
g.legend.set_title("")
g.fig.subplots_adjust(top=0.8)
g.fig.suptitle("Single-interval overfitting (RNAcov + SSProb + SSU + SJ)")

plt.show()

# %%
x = pd.concat([
    (
        X[
            ["epoch","run_name","rna_seq_1bp_profile_pearson_r_mean","splice_usage_pearson_r","splice_junctions_pearson_r"]
        ].drop_duplicates()
        .melt(id_vars=["epoch","run_name"], var_name="modality", value_name="metric_value")
        .assign(metric_name="correlation")
    ),
    (
        X[
            ["epoch","run_name","splice_site_auprc_macro"]
        ].drop_duplicates()
        .melt(id_vars=["epoch","run_name"], var_name="modality", value_name="metric_value")
        .assign(metric_name="auprc")
    )
])
x["modality"] = x["modality"].map({
    "rna_seq_1bp_profile_pearson_r_mean":"rna_seq",
    "splice_site_auprc_macro":"splice_site",
    "splice_usage_pearson_r":"splice_usage",
    "splice_junctions_pearson_r":"splice_junctions",
    "splice_junctions_pearson_r_nonzero":"splice_junctions",
    "splice_junctions_pearson_r_donor_marginal":"splice_junctions",
    "splice_junctions_pearson_r_acceptor_marginal":"splice_junctions",
})

g = sns.relplot(
    kind="line",
    data=x,
    x="epoch",
    y="metric_value",
    hue="run_name", palette="tab20",
    col="modality", col_order=PAL_MODALITIES.keys(),
    linewidth=1, linestyle="dashed",
    facet_kws=dict(sharey=False),
    height=4*cm, aspect=0.9
)

g.set(
    xlabel="Epoch",
    ylabel="Metric"
)
g.legend.set_title("")
g.fig.subplots_adjust(top=0.8)
g.fig.suptitle("Single-interval overfitting (RNAcov + SSProb + SSU + SJ)")

plt.show()
